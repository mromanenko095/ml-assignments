# %% [markdown]
# <a href="https://colab.research.google.com/github/mromanenko095/ml-assignments/blob/main/Pandas_Matplotlib_Sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1KWlcYkMkDIZdATT2TTcnIfudNP-PSUci  # подключение к диску по id
# Все сохранилось в среду колаба
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KWlcYkMkDIZdATT2TTcnIfudNP-PSUci
# To: /content/titanic.csv
# 100% 61.2k/61.2k [00:00<00:00, 52.7MB/s]

# %%
# !ls  # смотрим что лежит в директории
# Out:
# drive  sample_data  titanic.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/titanic.csv /content/drive/MyDrive  # копируем файл на диск, можно через mv (move)

# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
a = [1, 7, 2]

series = pd.Series(a)

series
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
series.loc[1]
# Out:
# np.int64(7)

# %%
series.iloc[1]
# Out:
# np.int64(7)

# %%
series = pd.Series(a, index=['x', 'y', 'z'])
series
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
series.loc['x']
# Out:
# np.int64(1)

# %% [markdown]
# # DataFrame

# %%
data = {
    'calories': [420, 200, 438],
    'duration': [23, 21, 28]
}

# Ключи - названия строк

df = pd.DataFrame(data)
df.head()
# Out:
#    calories  duration
# 0       420        23
# 1       200        21
# 2       438        28

# %%
# Выведем столбец calories
df['calories']
# Out:
# 0    420
# 1    200
# 2    438
# Name: calories, dtype: int64

# %%
# Выведем строку 1
df.iloc[1]
# Out:
# calories    200
# duration     21
# Name: 1, dtype: int64

# %%
df.loc[1]
# Out:
# calories    200
# duration     21
# Name: 1, dtype: int64

# %% [markdown]
# # Создание DataFrame из файла

# %%
df = pd.read_csv('/content/titanic.csv', index_col='PassengerId')
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
df.sample(3)  # рандомная строка
# Out:
#              Survived  Pclass                        Name   Sex   Age  SibSp  \
# PassengerId
# 332                 0       1         Partner, Mr. Austen  male  45.5      0
# 109                 0       3             Rekic, Mr. Tido  male  38.0      0
# 203                 0       3  Johanson, Mr. Jakob Alfred  male  34.0      0
#
#              Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 332              0   113043  28.5000  C124        S
# 109              0   349249   7.8958   NaN        S
# 203              0  3101264   6.4958   NaN        S

# %%
df.tail(3)  # последние строки
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.loc[6]  # значения всех столбцов для этой строки
# Out:
# Survived                   0
# Pclass                     3
# Name        Moran, Mr. James
# Sex                     male
# Age                      NaN
# SibSp                      0
# Parch                      0
# Ticket                330877
# Fare                  8.4583
# Cabin                    NaN
# Embarked                   Q
# Name: 6, dtype: object

# %%
df.loc[6:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0  330877   8.4583   NaN        Q
# 7                0      0   17463  51.8625   E46        S
# 8                3      1  349909  21.0750   NaN        S
# ...

# %%
df.iloc[6:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 7                0      0   17463  51.8625   E46        S
# 8                3      1  349909  21.0750   NaN        S
# 9                0      2  347742  11.1333   NaN        S
# 10               1      0  237736  30.0708   NaN        C

# %%
df.loc[[6, 8, 16]]
# Out:
#              Survived  Pclass                              Name     Sex   Age  \
# PassengerId
# 6                   0       3                  Moran, Mr. James    male   NaN
# 8                   0       3    Palsson, Master. Gosta Leonard    male   2.0
# 16                  1       2  Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0  330877   8.4583   NaN        Q
# 8                3      1  349909  21.0750   NaN        S
# 16               0      0  248706  16.0000   NaN        S

# %%
df['Survived']
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
df.loc[9, 'Survived']
# Out:
# np.int64(1)

# %%
df.loc[7:9, 'Survived']
# Out:
# PassengerId
# 7    0
# 8    0
# 9    1
# Name: Survived, dtype: int64

# %%
df.loc[[7, 8, 92, 33], 'Survived']
# Out:
# PassengerId
# 7     0
# 8     0
# 92    0
# 33    1
# Name: Survived, dtype: int64
